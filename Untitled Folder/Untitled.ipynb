# %%
import requests
import pandas as pd

# %%
url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockPrice",
    "data_id": "00881",
    "start_date": "2020-12-10",
    "end_date": "2021-09-24",
    "token": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJkYXRlIjoiMjAyMS0wOS0yNCAxNzo0ODoxNSIsInVzZXJfaWQiOiJzbWlsZWJubmJubiIsImlwIjoiMTE4LjIzMy4xNDYuNTgifQ.Y1YaPDAqoptM_-My-ai6l6Pnu0s1uh7mlwSF8LJpkIc", # 參考登入，獲取金鑰
}
res = requests.get(url, params=parameter)
data = res.json()
data = pd.DataFrame(data["data"])
data.set_index("date", inplace = True)
data
# Out:
#            stock_id  Trading_Volume  Trading_money   open    max    min  \
# date
# 2020-12-10    00881       167235827     2559951430  15.21  15.62  15.11
# 2020-12-11    00881       215449379     3243440337  15.10  15.12  15.00
# 2020-12-14    00881       137488878     2043374419  14.91  14.91  14.82
# 2020-12-15    00881        94640143     1395236409  14.81  14.86  14.67
# 2020-12-16    00881        38406024      569937121  14.76  14.88  14.76
# ...             ...             ...            ...    ...    ...    ...
# 2021-09-16    00881        15967899      279696669  17.60  17.65  17.45
# 2021-09-17    00881        10547253      185344748  17.52  17.69  17.45
# 2021-09-22    00881        41754107      720428464  17.29  17.33  17.20
# 2021-09-23    00881         7147383      124603590  17.40  17.49  17.37
# 2021-09-24    00881         5382666       94406413  17.50  17.57  17.50
#
#             close  spread  Trading_turnover
# date
# 2020-12-10  15.30    0.19             49019
# ...

# %%
data[]
